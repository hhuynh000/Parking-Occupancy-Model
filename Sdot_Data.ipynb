# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime, date, time

# %%
directory = './data/ground_truth/sdot/2022_01'

# %%
occ = pd.DataFrame()

# %%
col_name = None
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if not filename.startswith('.') and os.path.isfile(f):
        df = pd.read_csv(f)
        if len(occ.columns) == 0 or df.columns.values.tolist() == occ.columns.values.tolist():
            occ = pd.concat([occ, df], ignore_index=True)

# %%
def convert_time(timestr):
    try:
        return datetime.strptime(timestr, '%I%p').time()
    except:
        return np.nan
    
def convert_date(datestr):
    try:
        return datetime.strptime(datestr, '%m/%d/%Y').date()
    except:
        return np.nan

# %%
occ = occ.drop(columns=['Unnamed: 0','Route','Label','Load Zone','RPZ for that Block','ADA','Rideshare','ILLEGAL','Notes','Pictures'])
occ['Time'] = occ.apply(lambda r: convert_time(r['Time']), axis=1)
occ['Date'] = occ.apply(lambda r: convert_date(r['Date']), axis=1)
occ.dropna(subset=['Time','Date','Element Key'], inplace=True)
occ['Element Key'] = occ.apply(lambda r: int(r['Element Key']), axis=1)
occ = occ.sort_values(by=['Element Key', 'Date', 'Time'])

# %%
occ.head()
# Out:
#            Time        Date  Element Key  \
# 17549  09:00:00  2021-10-27         1001
# 17550  10:00:00  2021-10-27         1001
# 17551  11:00:00  2021-10-27         1001
# 17552  12:00:00  2021-10-27         1001
# 17553  13:00:00  2021-10-27         1001
#
#                                         Location Side of Street  PAID
# 17549  1ST AVE BETWEEN CHERRY ST AND COLUMBIA ST             SW     5
# 17550  1ST AVE BETWEEN CHERRY ST AND COLUMBIA ST             SW     5
# 17551  1ST AVE BETWEEN CHERRY ST AND COLUMBIA ST             SW     5
# 17552  1ST AVE BETWEEN CHERRY ST AND COLUMBIA ST             SW     5
# 17553  1ST AVE BETWEEN CHERRY ST AND COLUMBIA ST             SW     5

# %%
grouped = occ.groupby(['Element Key','Date'])
groups = grouped.filter(lambda r: len(r.index) == 12)

# %%
groups = groups.reset_index(drop=True)
groups.head(50)
# Out:
#         Time        Date  Element Key  \
# 0   08:00:00  2022-04-29         1013
# 1   09:00:00  2022-04-29         1013
# 2   10:00:00  2022-04-29         1013
# 3   11:00:00  2022-04-29         1013
# 4   12:00:00  2022-04-29         1013
# 5   13:00:00  2022-04-29         1013
# 6   14:00:00  2022-04-29         1013
# 7   15:00:00  2022-04-29         1013
# 8   16:00:00  2022-04-29         1013
# 9   17:00:00  2022-04-29         1013
# 10  18:00:00  2022-04-29         1013
# 11  19:00:00  2022-04-29         1013
# 12  08:00:00  2022-08-22         1013
# 13  09:00:00  2022-08-22         1013
# 14  10:00:00  2022-08-22         1013
# 15  11:00:00  2022-08-22         1013
# 16  12:00:00  2022-08-22         1013
# 17  13:00:00  2022-08-22         1013
# 18  14:00:00  2022-08-22         1013
# 19  15:00:00  2022-08-22         1013
# 20  16:00:00  2022-08-22         1013
# 21  17:00:00  2022-08-22         1013
# 22  18:00:00  2022-08-22         1013
# 23  19:00:00  2022-08-22         1013
# 24  08:00:00  2022-04-29         1014
# 25  09:00:00  2022-04-29         1014
# 26  10:00:00  2022-04-29         1014
# 27  11:00:00  2022-04-29         1014
# 28  12:00:00  2022-04-29         1014
# 29  13:00:00  2022-04-29         1014
# 30  14:00:00  2022-04-29         1014
# 31  15:00:00  2022-04-29         1014
# 32  16:00:00  2022-04-29         1014
# 33  17:00:00  2022-04-29         1014
# 34  18:00:00  2022-04-29         1014
# 35  19:00:00  2022-04-29         1014
# 36  08:00:00  2022-08-22         1014
# 37  09:00:00  2022-08-22         1014
# 38  10:00:00  2022-08-22         1014
# 39  11:00:00  2022-08-22         1014
# 40  12:00:00  2022-08-22         1014
# 41  13:00:00  2022-08-22         1014
# 42  14:00:00  2022-08-22         1014
# 43  15:00:00  2022-08-22         1014
# 44  16:00:00  2022-08-22         1014
# 45  17:00:00  2022-08-22         1014
# 46  18:00:00  2022-08-22         1014
# 47  19:00:00  2022-08-22         1014
# 48  08:00:00  2022-05-03         1017
# 49  09:00:00  2022-05-03         1017
#
#                                        Location Side of Street  PAID
# 0   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     2
# 1   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     0
# 2   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     1
# 3   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     0
# 4   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     1
# 5   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     1
# 6   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     3
# 7   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     4
# 8   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     5
# 9   1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     4
# 10  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     5
# 11  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     4
# 12  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     3
# 13  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     3
# 14  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     4
# 15  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     4
# 16  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     4
# 17  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     4
# 18  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     3
# 19  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     3
# 20  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     2
# 21  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     2
# 22  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     2
# 23  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             SW     3
# 24  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 25  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     9
# 26  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE    10
# 27  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE    10
# 28  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE    10
# 29  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     9
# 30  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     8
# 31  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     3
# 32  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 33  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 34  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 35  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     9
# 36  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 37  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     1
# 38  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     9
# 39  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     9
# 40  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE    10
# 41  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     9
# 42  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     7
# 43  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 44  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 45  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 46  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     0
# 47  1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST             NE     8
# 48   1ST AVE BETWEEN STEWART ST AND VIRGINIA ST             SW     0
# 49   1ST AVE BETWEEN STEWART ST AND VIRGINIA ST             SW     2

# %%
groups.tail()
# Out:
#           Time        Date  Element Key  \
# 9631  15:00:00  2022-04-27       136322
# 9632  16:00:00  2022-04-27       136322
# 9633  17:00:00  2022-04-27       136322
# 9634  18:00:00  2022-04-27       136322
# 9635  19:00:00  2022-04-27       136322
#
#                                                Location Side of Street  PAID
# 9631  NE PACIFIC ST BETWEEN BROOKLYN AVE NE AND UNIV...              N     5
# 9632  NE PACIFIC ST BETWEEN BROOKLYN AVE NE AND UNIV...              N     3
# 9633  NE PACIFIC ST BETWEEN BROOKLYN AVE NE AND UNIV...              N     1
# 9634  NE PACIFIC ST BETWEEN BROOKLYN AVE NE AND UNIV...              N     0
# 9635  NE PACIFIC ST BETWEEN BROOKLYN AVE NE AND UNIV...              N     0

# %%
block_data = groups.drop_duplicates(subset=["Date", "Element Key"], keep="first")
block_data = block_data.drop(columns=["Time","Location","Side of Street","PAID"])

# %%
block_data.head(1000)
# Out:
#             Date  Element Key
# 0     2022-04-29         1013
# 12    2022-08-22         1013
# 24    2022-04-29         1014
# 36    2022-08-22         1014
# 48    2022-05-03         1017
# ...          ...          ...
# 9576  2022-08-22       123943
# 9588  2022-05-05       131238
# 9600  2022-04-29       136041
# 9612  2022-08-22       136041
# 9624  2022-04-27       136322
#
# [803 rows x 2 columns]

# %%
block_data.to_csv("data/sdot_12.csv",index=False)
