# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import MDP as mdp
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn import kernel_ridge
from tqdm import tqdm

# %% [markdown]
# ## Read Data

# %%
X_data = pd.read_csv('./data/X_data.csv')
X_data = np.array(X_data.values.tolist())
X_data = X_data[:,3]
X_data = X_data.reshape((84,720))

Y_data = pd.read_csv('./data/Y_data.csv')
Y_data = np.array(Y_data.values.tolist())
Y_data = Y_data[:,1]
Y_data = Y_data.reshape((84,720))

block_names = pd.read_csv('./data/block_names.csv')
block_names = np.array(block_names['0'].tolist())

# %% [markdown]
# ## Split Training/Test Data

# %%
x_train, x_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=1/7, random_state=142)
print('Training Data Size:', len(x_train))
print('Testing Data Size:', len(x_test))
# Out:
# Training Data Size: 72
# Testing Data Size: 12

# %% [markdown]
# ## K-Mean Clustering

# %%
n_clusters = 4
kmeans = KMeans(n_clusters)
kmeans.fit(x_train)
clusters = kmeans.predict(x_train)
print(len(clusters))
# Out:
# 72

# %%
x_bins = [[], [], [], []]
y_bins = [[], [], [], []]
label_bins = [[], [], [], []]
for i, cluster in enumerate(clusters):
    x_bins[cluster].append(x_train[i])
    y_bins[cluster].append(y_train[i])
    label_bins[cluster].append(block_names[i])

# %%
# To visualize the data use PCA to reduce dimension to 2 and plot scatter plot
pca_2d = PCA(n_components=2)
PCA_2d = pca_2d.fit_transform(x_train)

# %%
colors = ['b', 'g', 'r', 'm', 'y']
color_map = []
for index in clusters:
    color_map.append(colors[index])
plt.figure(figsize=(10,6))
plt.scatter(PCA_2d[:,0], PCA_2d[:,1], color=color_map)
plt.title("Naive Parking Occupancy Clusters", fontsize=20)
plt.ylabel("Principle Component 2", fontsize=15)
plt.xlabel("Principle Component 1", fontsize=15)
plt.show()

# %% [markdown]
#  ## Based Case Test

# %%
lambda_val = 0.1
gamma = 0.001
rrg = kernel_ridge.KernelRidge(alpha=lambda_val, kernel='rbf', gamma=gamma)

# %%
rrg.fit(x_train, y_train)
y_pred = rrg.predict(x_test)
mae = np.mean(np.abs(y_test-y_pred))
print('Base Case Accuracy:', 1-mae)
# Out:
# Base Case Accuracy: 0.8419585284976585

# %% [markdown]
# ## Q-Learning

# %%
train_data = (x_bins, y_bins)
test_data = (x_test, y_test)
max_bins = [len(x_bins[i]) for i in range(n_clusters)]
print('max bins:', max_bins)
# Out:
# max bins: [7, 34, 16, 15]

# %%
model = mdp.BanditMDP(train_data, test_data, max_bins)
samples = 36
model.set_goal(samples)
print(model.operators)
print(model.action_to_index)
# Out:
# [0, 1, -1, 2, -2, 3, -3, 4, -4]
# {0: 0, 1: 1, -1: 2, 2: 3, -2: 4, 3: 5, -3: 6, 4: 7, -4: 8}

# %%
# Need about 10000000 iterations to converge
n_iteration = 100000000
for i in tqdm(range(n_iteration)):
    model.run_iteration()
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 100000000/100000000 [17:19<00:00, 96185.45it/s]

# %%
model.get_policy()

# %%
sol = model.get_solution()
# Out:
# curr_state [0, 0, 0, 0]
# action: 1
# curr_state [1, 0, 0, 0]
# action: 1
# curr_state [2, 0, 0, 0]
# action: 1
# curr_state [3, 0, 0, 0]
# action: 1
# curr_state [4, 0, 0, 0]
# action: 1
# curr_state [5, 0, 0, 0]
# action: 2
# curr_state [5, 1, 0, 0]
# action: 2
# curr_state [5, 2, 0, 0]
# action: 2
# curr_state [5, 3, 0, 0]
# action: 2
# curr_state [5, 4, 0, 0]
# action: 2
# curr_state [5, 5, 0, 0]
# action: 2
# curr_state [5, 6, 0, 0]
# action: 2
# curr_state [5, 7, 0, 0]
# action: 2
# curr_state [5, 8, 0, 0]
# action: 2
# curr_state [5, 9, 0, 0]
# action: 2
# curr_state [5, 10, 0, 0]
# action: 2
# curr_state [5, 11, 0, 0]
# action: 2
# curr_state [5, 12, 0, 0]
# action: 2
# curr_state [5, 13, 0, 0]
# action: 2
# curr_state [5, 14, 0, 0]
# action: 2
# curr_state [5, 15, 0, 0]
# action: 2
# curr_state [5, 16, 0, 0]
# action: 3
# curr_state [5, 16, 1, 0]
# action: 3
# curr_state [5, 16, 2, 0]
# action: 3
# curr_state [5, 16, 3, 0]
# action: 3
# curr_state [5, 16, 4, 0]
# action: 3
# curr_state [5, 16, 5, 0]
# action: 3
# curr_state [5, 16, 6, 0]
# action: 3
# curr_state [5, 16, 7, 0]
# action: 3
# curr_state [5, 16, 8, 0]
# action: 3
# curr_state [5, 16, 9, 0]
# action: 3
# curr_state [5, 16, 10, 0]
# action: 3
# curr_state [5, 16, 11, 0]
# action: 3
# curr_state [5, 16, 12, 0]
# action: 3
# curr_state [5, 16, 13, 0]
# action: 3
# curr_state [5, 16, 14, 0]
# action: 4
# Solution State [5, 16, 14, 1]
# Accuracy 0.8448030820574978

# %%
index = np.argsort(sol)[::-1][:2]
print(index)
# Out:
# [1 2]

# %% [markdown]
# ## RL case

# %%
rlx_train = np.concatenate((x_bins[index[0]], x_bins[index[1]]))
rly_train = np.concatenate((y_bins[index[0]], y_bins[index[1]]))
rrg.fit(rlx_train, rly_train)
y_pred = rrg.predict(x_test)
mae = np.mean(np.abs(y_test-y_pred))
print('Base Case Accuracy:', 1-mae)
# Out:
# Base Case Accuracy: 0.8421706958977474

# %%
index = [2,3]
rlx_train = np.concatenate((x_bins[index[0]], x_bins[index[1]]))
rly_train = np.concatenate((y_bins[index[0]], y_bins[index[1]]))
rrg.fit(rlx_train, rly_train)
y_pred = rrg.predict(x_test)
mae = np.mean(np.abs(y_test-y_pred))
print('Base Case Accuracy:', 1-mae)
# Out:
# Base Case Accuracy: 0.7517731405048717
